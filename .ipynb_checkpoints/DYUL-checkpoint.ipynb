# %%
import ROOT
from IPython.display import IFrame
import FitSignal
import os
# Out:
# Welcome to JupyROOT 6.12/07

# %%
can = ROOT.TCanvas("can", "canvas", 800, 800)
f1 = ROOT.TFile("nano2pico/dyReco.root")
h1 = f1.Get("h1")
h1.Draw()
can.Draw()
print h1.Integral()
# Out:
# 20562.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: can

# %%
can = ROOT.TCanvas("can", "canvas", 800, 800)
f1 = ROOT.TFile("nano2pico/dyUL.root")
h1 = f1.Get("h1")
h1.Draw()
can.Draw()
print h1.Integral()
# Out:
# 34329.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: can
