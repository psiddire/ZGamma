# %%
import os
from sys import argv, stdout, stderr
from ROOT import TFile, gROOT, TCanvas, TLegend
import ROOT
import sys                                                                                                                                                                                                                                                  
gROOT.SetStyle("Plain")                                                                                                                                                                                                                                           
gROOT.SetBatch(True)

# %%
import rootnotes
c1=rootnotes.default_canvas()

# %%
f = TFile("dataws_single_vbf.root")
#f.ls()
ws = f.Get("CMS_emu_workspace")
ws.Print()
# Out:
# RooWorkspace(CMS_emu_workspace) CMS_emu_workspace contents
#
# variables
# ---------
# (CMS_emu_Mass,IntLumi,SqrtS)
#
# datasets
# --------
# RooDataSet::Data_13TeV_vbf(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf1a(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf2a(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf3a(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf4a(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf5a(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf6a(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf7a(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf8a(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf9a(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf1b(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf2b(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf3b(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf4b(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf5b(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf6b(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf7b(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf8b(CMS_emu_Mass)
# RooDataSet::Data_13TeV_vbf9b(CMS_emu_Mass)

# %%
mass = ROOT.RooRealVar("CMS_emu_Mass","CMS_emu_Mass", 100, 180)
data = ws.data("")

# %%
xframe = mass.frame()
data.plotOn(xframe)
xframe.Draw()
c1
# Out:
# <ROOT.TCanvas object ("icanvas") at 0xb1ad8a0>
# Info in <TCanvas::Print>: png file /tmp/tmpLQniJv.png has been created
