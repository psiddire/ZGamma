# %%
from IPython.display import IFrame

# %%
import ROOT
ROOT.gSystem.Load('ModGaus_cxx.so')
ROOT.gSystem.Load('ModGaus01_cxx.so')
ROOT.gSystem.Load('ModGaus10_cxx.so')
ROOT.gSystem.Load('ModGaus11_cxx.so')
ROOT.gSystem.Load('ModGaus21_cxx.so')
ROOT.TGaxis.SetMaxDigits(3)

# %%
defaults = [120, 2.5, 0, 10, 10, 50, 0, 0, 50]
xlow = 100
xhigh = 180
fitType = "ModGaus01"
category = "Inclusive"

m = ROOT.RooRealVar("llphoton_m", "ll#gamma mass [GeV]", xlow, xhigh)
m0 = ROOT.RooRealVar("m_{0}", "mass peak value [GeV]", defaults[0], 105, 145)
m0.setError(1.0)
vl = ROOT.RooRealVar("#nu_{L}", "low-end power", defaults[1], 0, 5)
vl.setError(0.1)
vr = ROOT.RooRealVar("#Delta#nu", "power range", defaults[2], -5, 5)
vr.setError(0.1)
s0 = ROOT.RooRealVar("#sigma_{0}", "peak width", defaults[3], 1, 40)
s0.setError(1.0)
sl = ROOT.RooRealVar("#sigma_{L}", "low-end width", defaults[4], 1, 40)
sl.setError(1.0)
sh = ROOT.RooRealVar("#sigma_{H}", "high-end width", defaults[5], 20, 100)
sh.setError(1.0)
s1 = ROOT.RooRealVar("#sigma_{1}", "1st order width", defaults[6], 1, 40)
s1.setError(1.0)
s2 = ROOT.RooRealVar("#sigma_{2}", "2nd order width", defaults[7], -50, 50)
s2.setError(1.0)
v0 = ROOT.RooRealVar("#nu_{0}", "0th order power", 2.5, 0, 5)
v0.setError(0.1)
v1 = ROOT.RooRealVar("#nu_{1}", "1st order power", 2.5, 0, 5)
v1.setError(0.1)

if fitType == "ModGaus21":
    background = ROOT.ModGaus21("background", "G_{2, 1}", m, m0, vl, vr, s0, s1, s2)
elif fitType == "ModGaus11":
    background = ROOT.ModGaus11("background", "G_{1, 1}", m, m0, vl, vr, s0, s1)
elif fitType == "ModGaus10":
    background = ROOT.ModGaus10("background", "G_{1, 0}", m, m0, vl, vr, s0)
elif fitType == "ModGaus01":
    background = ROOT.ModGaus01("background", "G_{0, 1}", m, m0, vl, s0, s1)
else:
    background = ROOT.ModGaus("background", "G_{M}", m, m0, vl, vr, s0, sl, sh)

inpath = "Data.root"
infile = ROOT.TFile(inpath)

hmc = infile.Get("h_llg")

data = ROOT.RooDataHist(category, category, ROOT.RooArgList(m), ROOT.RooFit.Import(hmc))

m.setRange("full", 100, 180)
m.setRange("left", 100, 120)
m.setRange("right", 130, 180)
 
blindedData = data.reduce(ROOT.RooFit.CutRange("left, right"))

fitResult = background.fitTo(blindedData)

canvas = ROOT.TCanvas("canvas","canvas",800,600)
canvas.Divide(2,1)

canvas.cd(1)

plotFrame = m.frame(ROOT.RooFit.Title("Wrong: Each slice normalised over its plotting range"))

blindedData.plotOn(plotFrame)

background.plotOn(plotFrame, ROOT.RooFit.LineColor(ROOT.kRed),   ROOT.RooFit.Range("full"))
background.plotOn(plotFrame, ROOT.RooFit.LineColor(ROOT.kBlue),  ROOT.RooFit.Range("left"))
background.plotOn(plotFrame, ROOT.RooFit.LineColor(ROOT.kGreen), ROOT.RooFit.Range("right"))
 
plotFrame.Draw()
  
canvas.cd(2)

plotFrameWithNormRange = m.frame(ROOT.RooFit.Title("Right: All slices have common normalisation"))
 
blindedData.plotOn(plotFrameWithNormRange)
background.plotOn(plotFrameWithNormRange, ROOT.RooFit.LineColor(ROOT.kBlue),  ROOT.RooFit.Range("left"),  ROOT.RooFit.NormRange("left,right"))
background.plotOn(plotFrameWithNormRange, ROOT.RooFit.LineColor(ROOT.kGreen), ROOT.RooFit.Range("right"), ROOT.RooFit.NormRange("left,right"))
background.plotOn(plotFrameWithNormRange, ROOT.RooFit.LineColor(ROOT.kRed),   ROOT.RooFit.Range("full"),  ROOT.RooFit.NormRange("left,right"), ROOT.RooFit.LineStyle(10))
 
plotFrameWithNormRange.Draw()

canvas.Draw()
# Out:
# [#1] INFO:DataHandling -- RooDataHist::adjustBinning(Inclusive): fit range of variable llphoton_m expanded to nearest bin boundaries: [100,180] --> [100,180]
# [#1] INFO:Eval -- RooRealVar::setRange(llphoton_m) new range named 'full' created with bounds [100,180]
# [#1] INFO:Eval -- RooRealVar::setRange(llphoton_m) new range named 'left' created with bounds [100,120]
# [#1] INFO:Eval -- RooRealVar::setRange(llphoton_m) new range named 'right' created with bounds [130,180]
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
#  **********
#  **   28 **SET PRINT           1
#  **********
#  **********
#  **   29 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 #nu_{L}      2.50000e+00  1.00000e-01    0.00000e+00  5.00000e+00
#      2 #sigma_{0}   1.00000e+01  1.00000e+00    1.00000e+00  4.00000e+01
#      3 #sigma_{1}   2.05000e+01  1.00000e+00    1.00000e+00  4.00000e+01
#      4 m_{0}        1.20000e+02  1.00000e+00    1.05000e+02  1.45000e+02
#  **********
#  **   30 **SET ERR         0.5
#  **********
#  **********
#  **   31 **SET PRINT           1
#  **********
#  **********
#  **   32 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   33 **MIGRAD        2000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=200765 FROM MIGRAD    STATUS=INITIATE       16 CALLS          17 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  #nu_{L}      2.50000e+00   1.00000e-01   4.00107e-02   4.20661e+04
#    2  #sigma_{0}   1.00000e+01   1.00000e+00   6.09421e-02  -5.91039e+04
#    3  #sigma_{1}   2.05000e+01   1.00000e+00   5.13046e-02  -4.09858e+04
#    4  m_{0}        1.20000e+02   1.00000e+00   5.16674e-02  -1.01067e+04
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=187148 FROM MIGRAD    STATUS=CONVERGED     251 CALLS         252 TOTAL
#                      EDM=8.90963e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  #nu_{L}      1.94656e+00   4.17154e-02   3.98532e-03  -1.05094e-01
#    2  #sigma_{0}   1.01236e+01   1.73366e-01   2.14941e-03   3.18863e-01
#    3  #sigma_{1}   4.00000e+01   3.77795e-02   1.86923e-02** at limit **
#    4  m_{0}        1.15582e+02   1.09657e-01   1.45274e-03  -2.81053e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   1.740e-03  4.492e-03 -8.599e-08  2.045e-03
#   4.492e-03  3.006e-02  3.413e-07  1.174e-02
#  -8.599e-08  3.413e-07  1.813e-08  3.264e-07
#   2.045e-03  1.174e-02  3.264e-07  1.202e-02
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.62688   1.000  0.621 -0.015  0.447
#         2  0.72819   0.621  1.000  0.015  0.617
#         3  0.03974  -0.015  0.015  1.000  0.022
#         4  0.62296   0.447  0.617  0.022  1.000
#  **********
#  **   34 **SET ERR         0.5
#  **********
#  **********
#  **   35 **SET PRINT           1
#  **********
#  **********
#  **   36 **HESSE        2000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=187148 FROM HESSE     STATUS=OK             23 CALLS         275 TOTAL
#                      EDM=8.80091e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  #nu_{L}      1.94656e+00   4.19260e-02   1.59413e-04  -2.23224e-01
#    2  #sigma_{0}   1.01236e+01   1.74346e-01   8.59763e-05  -5.61106e-01
#    3  #sigma_{1}   4.00000e+01   3.77904e-02   3.73845e-03   1.57091e+00
#                                  WARNING -   - ABOVE PARAMETER IS AT LIMIT.
#    4  m_{0}        1.15582e+02   1.10109e-01   2.90548e-04  -4.90331e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   1.758e-03  4.578e-03 -1.749e-08  2.095e-03
#   4.578e-03  3.040e-02  7.303e-08  1.193e-02
#  -1.749e-08  7.303e-08  1.814e-08  6.907e-08
#   2.095e-03  1.193e-02  6.907e-08  1.212e-02
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.63171   1.000  0.626 -0.003  0.454
#         2  0.73180   0.626  1.000  0.003  0.622
#         3  0.00831  -0.003  0.003  1.000  0.005
#         4  0.62701   0.454  0.622  0.005  1.000
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(background) only plotting range 'full', curve is normalized to data in given given range
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m|full]_Norm[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(background) only plotting range 'left', curve is normalized to data in given given range
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m|left]_Norm[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(background) only plotting range 'right', curve is normalized to data in given given range
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m|right]_Norm[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(background) only plotting range 'left'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(background) p.d.f. curve is normalized using explicit choice of ranges 'left,right'
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m|left]_Norm[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m|right]_Norm[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(background) only plotting range 'right'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(background) p.d.f. curve is normalized using explicit choice of ranges 'left,right'
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m|left]_Norm[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m|right]_Norm[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(background) only plotting range 'full'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(background) p.d.f. curve is normalized using explicit choice of ranges 'left,right'
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m|left]_Norm[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(background_Int[llphoton_m|right]_Norm[llphoton_m]) using numeric integrator RooIntegrator1D to calculate Int(llphoton_m)
# Info in ROOT::Math::ParameterSettings>: lower/upper bounds outside current parameter value. The value will be set to (low+up)/2
# Info in ROOT::Math::ParameterSettings>: lower/upper bounds outside current parameter value. The value will be set to (low+up)/2
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
